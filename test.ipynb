# %%
import pandas as pd
import os
import json

# %%
# load in all the csv files from "data/test" and combine them into one dataframe
data_dir = "data/test"
all_files = os.listdir(data_dir)
print(all_files)
all_dfs = []
for file in all_files:
    if file.endswith(".csv"):
        df = pd.read_csv("data/test/" + file, sep=";")
        df['kommunenavn'] = file.replace(".csv", "")
        all_dfs.append(df)
combined_df = pd.concat(all_dfs, ignore_index=True)
# Out:
# ['københavn.csv', 'herlev.csv', 'faaborg-midtfyn.csv', 'helsingør.csv']

# %%
combined_df
# Out:
#       Afstemningsområde Bogstavbetegnelse                     Listenavn  \
# 0        1. 1. Østerbro                 A             Socialdemokratiet
# 1        1. 1. Østerbro                 A             Socialdemokratiet
# 2        1. 1. Østerbro                 A             Socialdemokratiet
# 3        1. 1. Østerbro                 A             Socialdemokratiet
# 4        1. 1. Østerbro                 A             Socialdemokratiet
# ...                 ...               ...                           ...
# 19821  12. Toldkammeret                 Ø  Enhedslisten - De Rød-Grønne
# 19822  12. Toldkammeret                 Å                  Alternativet
# 19823  12. Toldkammeret                 Å                  Alternativet
# 19824  12. Toldkammeret                 Å                  Alternativet
# 19825  12. Toldkammeret                 Å                  Alternativet
#
#                                 Navn  Stemmetal kommunenavn
# ...

# %%
combined_df.to_csv("data/test/combined.csv", index=False)

# %%
# loop over the file data/struktureret/kv25_valgforbund_data.csv and print the kommunenavn column
df = pd.read_csv("data/struktureret/kv25_valgforbund_data.csv")

kommuner_DK = []

for index, row in df.iterrows():
    kommuner_DK.append({
        'kommune' : row['kommune'],
        'kommune_dagi_id' : row['kommune_dagi_id'],
        'chart_id' : None,
        'table_id' : None,
        'map_id' : None,
        })

# remove duplicates based on the kommune column
kommuner_DK = [dict(t) for t in {tuple(d.items()) for d in kommuner_DK}]

    
# save it as a json file
with open("data/struktureret/kommuner_DK.json", "w") as f:
    json.dump(kommuner_DK, f, indent=4)

# %%
# load in the geojsons in data/struktureret/shapes and convert them to topojsons using mapshaper
shapes_dir = "data/shapes"
all_files = os.listdir(shapes_dir)
for file in all_files:
    if file.endswith(".geojson"):
        os.system(f"npx mapshaper {shapes_dir}/{file} -o format=topojson {shapes_dir}/{file.replace('.geojson', '.topojson')}")
# Out:
# npm warn exec The following package was not found and will be installed: mapshaper@0.6.113
# npm warn deprecated geographiclib@1.48.0: This package has been split into geographic-geodesic + geographiclib-dms; use one or both of these instead of geographiclib.  WARNING: there's a potential buffer overrun on this package.  SWITCH TO THE NEW PACKAGES NOW.
# [o] Wrote data/shapes/hillerød_afstemningsområder.topojson
# npm notice
# npm notice New major version of npm available! 10.9.0 -> 11.6.1
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v11.6.1
# npm notice To update run: npm install -g npm@11.6.1
# npm notice
# [o] Wrote data/shapes/norddjurs_afstemningsområder.topojson
# [o] Wrote data/shapes/næstved_afstemningsområder.topojson
# [o] Wrote data/shapes/vesthimmerlands_afstemningsområder.topojson
# [o] Wrote data/shapes/christiansø_afstemningsområder.topojson
# [o] Wrote data/shapes/helsingør_afstemningsområder.topojson
# ...

# %%
import pandas as pd
import paramiko
import os
import re
import json

# %%
# FTP login information
host = "data.valg.dk"
port = 22
username = "Valg"
password = "Valg"

# Forbindelse til FTP-server
transport = paramiko.Transport((host, port))
transport.connect(username=username, password=password)
sftp = paramiko.SFTPClient.from_transport(transport)

# %%
sftp.listdir('data/kommunalvalg-134-18-11-2025/')
# Out:
# ['geografi',
#  'public-key.pem',
#  'verifikation',
#  'Snitfladebeskrivelser',
#  'kandidat-data']

# %%
with sftp.open('data/kommunalvalg-134-18-11-2025/Snitfladebeskrivelser/Valgresultater/KVRV-Valgresultater.schema.json') as f:
    text = f.read().decode('latin-1')  # or 'windows-1252'
    data = json.loads(text)

# %%
data
# Out:
# {'$schema': 'http://json-schema.org/draft-04/schema#',
#  'title': 'KVRV-Valgresultater',
#  'type': 'object',
#  'additionalProperties': False,
#  'required': ['Kandidatlister',
#   'GodkendelsesDatoUTC',
#   'Valgdag',
#   'Valgart',
#   'FrigivelsesTidspunktUTC',
#   'Storkreds',
#   'Storkredsnummer',
#   'Opstillingskreds',
#   'OpstillingskredsDagiId',
#   'Kommune',
#   'Kommunekode',
#   'AfstemningsområdeNummer',
#   'AfstemningsområdeDagiId',
#   'Afstemningsområde',
#   'UgyldigeFremmødteStemmerÅrsager',
#   'UgyldigeBrevstemmerÅrsager',
#   'Resultatart',
#   'AfgivneStemmer',
#   'GyldigeStemmer',
#   'UgyldigeStemmerUdoverBlanke',
#   'BlankeUgyldigeFremmødteStemmer',
#   'BlankeUgyldigeBrevstemmer',
#   'AfgivneStemmerDifferenceFraForrigeValg',
#   'GyldigeStemmerDifferenceFraForrigeValg',
#   'UgyldigeStemmerDifferenceFraForrigeValg',
#   'BlankeStemmerDifferenceFraForrigeValg',
#   'AntalStemmeberettigedeVælgereDifferenceFraForrigeValg',
#   'AntalStemmeberettigedeVælgere'],
#  'properties': {'Valgdag': {'type': 'string',
#    'description': 'Dato for valget',
#    'format': 'date',
#    'pattern': '^(0[1-9]|[12][0-9]|3[01])-(0[1-9]|1[0-2])-(\\d{4})$'},
#   'Valgart': {'description': 'Navn på valget fx.: Folketingsvalg.',
#    'oneOf': [{'$ref': '#/definitions/Valgart'}]},
#   'FrigivelsesTidspunktUTC': {'type': 'string',
#    'description': 'UTC DateTime for filens oprettelse.',
#    'format': 'date-time',
#    'pattern': '^(0[1-9]|[12][0-9]|3[01])-(0[1-9]|1[0-2])-(\\d{4}) (0[0-9]|1[0-9]|2[0-3]):([0-5][0-9]):([0-5][0-9])$'},
#   'Storkreds': {'type': ['null', 'string'],
#    'description': 'Navn på storkredsen.'},
#   'Storkredsnummer': {'type': ['integer', 'null'],
#    'description': 'Storkredsnummer for storkredsen.',
#    'format': 'int32'},
#   'Opstillingskreds': {'type': ['null', 'string'],
#    'description': 'Navn på opstillingskredsen'},
#   'OpstillingskredsDagiId': {'type': ['integer', 'null'],
#    'description': 'DAGI id for opstillingskredsen',
#    'format': 'int32'},
#   'Kommune': {'type': 'string', 'description': 'Navn på kommunen'},
#   'Kommunekode': {'type': 'integer',
#    'description': 'Kode på kommunen',
#    'format': 'int32'},
#   'AfstemningsområdeNummer': {'type': 'integer',
#    'description': 'Nummeret på afstemningsområdet',
#    'format': 'int32'},
#   'AfstemningsområdeDagiId': {'type': 'integer',
#    'description': 'Afstemningsområde Id i DAGI',
#    'format': 'int32'},
#   'Afstemningsområde': {'type': 'string', 'description': 'Navn på valgområde'},
#   'UgyldigeFremmødteStemmerÅrsager': {'type': 'array',
#    'description': 'Ugyldige fremmødte stemme årsager.',
#    'items': {'$ref': '#/definitions/InvalidVoteReasonDto'}},
#   'UgyldigeBrevstemmerÅrsager': {'type': 'array',
#    'description': 'Ugyldige brevstemmer årsager.',
#    'items': {'$ref': '#/definitions/InvalidVoteReasonDto'}},
#   'Resultatart': {'description': "{Streng af 3 forskellige typer: ['IngenResultater - Resultaterne indeholder kun information om stemmeberettigede vælgere', 'ForeløbigOptælling -  Resultaterne er fra den foreløbige optælling', 'Fintælling - Resultaterne er fra fintælling' ]",
#    'oneOf': [{'$ref': '#/definitions/Resultatart'}]},
#   'AfgivneStemmer': {'type': 'integer',
#    'description': 'Summen af gyldige, ugyldige og blanke stemmer',
#    'format': 'int32'},
#   'GyldigeStemmer': {'type': 'integer',
#    'description': 'Summen af stemmer på alle partier',
#    'format': 'int32'},
#   'UgyldigeStemmerUdoverBlanke': {'type': 'integer',
#    'description': 'Summen af ugyldige stemmer udover blanke',
#    'format': 'int32'},
#   'BlankeUgyldigeFremmødteStemmer': {'type': 'integer',
#    'description': 'Summen af blanke fremmødte stemmer',
#    'format': 'int32'},
#   'BlankeUgyldigeBrevstemmer': {'type': 'integer',
#    'description': 'Summen af blanke brevstemmer',
#    'format': 'int32'},
#   'AfgivneStemmerDifferenceFraForrigeValg': {'type': ['integer', 'null'],
#    'description': 'Differencen af afgivne stemmer for det forrige valg',
#    'format': 'int32'},
#   'GyldigeStemmerDifferenceFraForrigeValg': {'type': ['integer', 'null'],
#    'description': 'Differencen af gyldige stemmer for det forrige valg',
#    'format': 'int32'},
#   'UgyldigeStemmerDifferenceFraForrigeValg': {'type': ['integer', 'null'],
#    'description': 'Differencen af ugyldige stemmer for det forrige valg',
#    'format': 'int32'},
#   'BlankeStemmerDifferenceFraForrigeValg': {'type': ['integer', 'null'],
#    'description': 'Differencen af blanke stemmer for det forrige valg',
#    'format': 'int32'},
#   'AntalStemmeberettigedeVælgereDifferenceFraForrigeValg': {'type': ['integer',
#     'null'],
#    'description': 'Differencen af antallet af stemmeberettigede vælgere fra forrige valg',
#    'format': 'int32'},
#   'AntalStemmeberettigedeVælgere': {'type': 'integer',
#    'description': 'Antallet af stemmeberettigede vælgere',
#    'format': 'int32'},
#   'Kandidatlister': {'type': 'array',
#    'description': 'Indeholder en liste af Kandidatliste objekter.',
#    'items': {'$ref': '#/definitions/CandidateListResultExportDto'}},
#   'GodkendelsesDatoUTC': {'type': ['null', 'string'],
#    'description': 'UTC-tidspunkt for godkendelse af resultaterne',
#    'format': 'date-time',
#    'pattern': '^(0[1-9]|[12][0-9]|3[01])-(0[1-9]|1[0-2])-(\\d{4}) (0[0-9]|1[0-9]|2[0-3]):([0-5][0-9]):([0-5][0-9])$'}},
#  'definitions': {'Valgart': {'type': 'string',
#    'enum': ['Europa-Parlamentsvalg',
#     'Folketingsvalg',
#     'Regionsrådsvalg',
#     'Kommunalvalg',
#     'Folkeafstemning']},
#   'InvalidVoteReasonDto': {'type': 'object',
#    'additionalProperties': False,
#    'required': ['Id', 'Navn', 'Paragraf', 'Antal'],
#    'properties': {'Id': {'type': 'integer',
#      'description': 'Identifikationsnummer på ugyldighedsårsagen',
#      'format': 'int32'},
#     'Navn': {'type': 'string', 'description': 'Navnet på ugyldighedsårsagen'},
#     'Paragraf': {'type': ['null', 'string'],
#      'description': 'Paragrafnumre som ugyldighedsårsagen omhandler'},
#     'Antal': {'type': 'integer',
#      'description': 'Antal ugyldige stemmer med årsagen',
#      'format': 'int32'}}},
#   'Resultatart': {'type': 'string',
#    'enum': ['ForeløbigOptælling', 'Fintælling', 'IngenResultater']},
#   'CandidateListResultExportDto': {'type': 'object',
#    'additionalProperties': False,
#    'required': ['KandidatlisteId',
#     'Navn',
#     'Bogstavbetegnelse',
#     'Stemmer',
#     'Listestemmer',
#     'StemmerDifferenceFraForrigeValg',
#     'Kandidater'],
#    'properties': {'KandidatlisteId': {'type': 'string',
#      'description': "Id'et på kandidatlisten",
#      'format': 'guid'},
#     'Navn': {'type': 'string', 'description': 'Navn på kandidatlisten'},
#     'Bogstavbetegnelse': {'type': ['null', 'string'],
#      'description': 'Bogstavbetegnelsen registreret på kandidatlisten'},
#     'Stemmer': {'type': 'integer',
#      'description': 'Totalen udregnet fra fremmødte stemmer og brevstemmer',
#      'format': 'int32'},
#     'Listestemmer': {'type': ['integer', 'null'],
#      'description': 'Antallet af stemmer specifikt på listen',
#      'format': 'int32'},
#     'StemmerDifferenceFraForrigeValg': {'type': ['integer', 'null'],
#      'description': 'Differencen fra det forrige valg',
#      'format': 'int32'},
#     'Kandidater': {'type': ['array', 'null'],
#      'description': 'Indeholder en liste af kandidat objekter for kandidater opstillet for den pågældende liste.',
#      'items': {'$ref': '#/definitions/Kandidat'}}}},
#   'Kandidat': {'type': 'object',
#    'additionalProperties': False,
#    'required': ['Id', 'Stemmeseddelnavn', 'Stemmer'],
#    'properties': {'Id': {'type': 'string',
#      'description': 'Identifikationsnummer på kandidaten',
#      'format': 'guid'},
#     'Stemmeseddelnavn': {'type': ['null', 'string'],
#      'description': 'Stemmeseddelnavnet på kandidaten'},
#     'Stemmer': {'type': 'integer',
#      'description': 'Totalen udregnet fra fremmødte stemmer og brevstemmer',
#      'format': 'int32'}}}}}

# %%
# with sftp.open('data/kommunalvalg-134-18-11-2025/geografi/Afstemningsomraade-291020251900.json') as f:
#     data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 with sftp.open('data/kommunalvalg-134-18-11-2025/geografi/Afstemningsomraade-291020251900.json') as f:
#       2     data = json.load(f)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/paramiko/sftp_client.py:372, in SFTPClient.open(self, filename, mode, bufsize)
#     370     imode |= SFTP_FLAG_CREATE | SFTP_FLAG_EXCL
#     371 attrblock = SFTPAttributes()
# --> 372 t, msg = self._request(CMD_OPEN, filename, imode, attrblock)
#     373 if t != CMD_HANDLE:
#     374     raise SFTPError("Expected handle")
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/paramiko/sftp_client.py:857, in SFTPClient._request(self, t, *args)
#     855 def _request(self, t, *args):
#     856     num = self._async_request(type(None), t, *args)
# --> 857     return self._read_response(num)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/paramiko/sftp_client.py:909, in SFTPClient._read_response(self, waitfor)
#     906 if num == waitfor:
#     907     # synchronous
#     908     if t == CMD_STATUS:
# --> 909         self._convert_status(msg)
#     910     return t, msg
#     912 # can not rewrite this to deal with E721, either as a None check
#     913 # nor as not an instance of None or NoneType
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/paramiko/sftp_client.py:938, in SFTPClient._convert_status(self, msg)
#     935     raise EOFError(text)
#     936 elif code == SFTP_NO_SUCH_FILE:
#     937     # clever idea from john a. meinel: map the error codes to errno
# --> 938     raise IOError(errno.ENOENT, text)
#     939 elif code == SFTP_PERMISSION_DENIED:
#     940     raise IOError(errno.EACCES, text)
#
# FileNotFoundError: [Errno 2] No such file

# %%
afstemningssteder = []

for d in data:

    afstemningssteder.append({
        'dagi_id': d['Dagi_id'],
        'navn': d['Navn'],
        'nummer': d['Nummer'],
        'afstemningssted_navn': d['Afstemningssted']['Navn'],
        'kommune_id': d['Kommunekode'],
        'opstillingskreds_nummer': d['Opstillingskredsnummer'],
        'opstillingskreds_dagi_id': d['Opstillingskreds_Dagi_id'],
        'afstemningssted_adresse': d['Afstemningssted']['Adgangsadresse']['Adressebetegnelse']
    })

df_afstemningssteder = pd.DataFrame(afstemningssteder)
df_afstemningssteder
# Out:
#      dagi_id                           navn  nummer  \
# 0     709812  Langå, Svindinge Og Øksendrup       5
# 1     748590                       Nymarken       3
# 2     706574                     Kerteminde       2
# 3     703760                      Skellerup       8
# 4     703754                   Nyborghallen       2
# ...      ...                            ...     ...
# 1309  707512                            Sig       4
# 1310  710690                          Ølgod      30
# 1311  708972                        Blåvand      19
# 1312  704694                        Agerbæk      23
# 1313  701482                        Ansager      32
#
#                            afstemningssted_navn  kommune_id  \
# 0                      Svindinge Forsamlingshus         450
# 1                                 Nymarksskolen         440
# 2                       Kerteminde Idrætscenter         440
# 3                      Skellerup Forsamlingshus         450
# 4                                  Nyborghallen         450
# ...                                         ...         ...
# 1309                   Birgittegården, Rød Stue         573
# 1310  Ølgod Hallen - Bemærk NYT afstemningssted         573
# 1311                          Blåvand Borgerhus         573
# 1312                              Agerbæk Hotel         573
# 1313       Skovlund-Ansager Hallen, Mini-hallen         573
#
#       opstillingskreds_nummer opstillingskreds_dagi_id  \
# 0                          46                   403614
# 1                          46                   403614
# 2                          46                   403614
# 3                          46                   403614
# 4                          46                   403614
# ...                       ...                      ...
# 1309                       54                   403620
# 1310                       54                   403620
# 1311                       54                   403620
# 1312                       54                   403620
# 1313                       54                   403620
#
#                      afstemningssted_adresse
# 0           Strædet 2, Svindinge, 5853 Ørbæk
# 1     Nymarken 47, Hundslev, 5300 Kerteminde
# 2                Enggade 19, 5300 Kerteminde
# 3         Skellerup Byvej 16, 5540 Ullerslev
# 4                      Halvej 1, 5800 Nyborg
# ...                                      ...
# 1309            Falkevej 4A, Sig, 6800 Varde
# 1310                Skolegade 18, 6870 Ølgod
# 1311            Blåvandvej 30A, 6857 Blåvand
# 1312               Storegade 7, 6753 Agerbæk
# 1313               Lærkevej 16, 6823 Ansager
#
# [1314 rows x 8 columns]

# %%
# load in the local kommune mapping file in json format
with open('data/kommuner.json') as f:
    kommune_info = json.load(f)

# %%
# join the kommune names to the afstemningssteder dataframe
df_afstemningssteder['kommune_navn'] = df_afstemningssteder['kommune_id'].astype(str).map(
    {k['kommune_id']: k['kommune_navn'] for k in kommune_info}
)

# map the kommune dagi ids
df_afstemningssteder['kommune_dagi_id'] = df_afstemningssteder['kommune_id'].astype(str).map(
    {k['kommune_id']: k['kommune_dagi_id'] for k in kommune_info}
)

# round the dagi id to integer and skip any errors
df_afstemningssteder['kommune_dagi_id'] = pd.to_numeric(df_afstemningssteder['kommune_dagi_id'], errors='coerce').round().astype('Int64')

# %%
df_afstemningssteder
# Out:
#      dagi_id                           navn  nummer  \
# 0     709812  Langå, Svindinge Og Øksendrup       5
# 1     748590                       Nymarken       3
# 2     706574                     Kerteminde       2
# 3     703760                      Skellerup       8
# 4     703754                   Nyborghallen       2
# ...      ...                            ...     ...
# 1309  707512                            Sig       4
# 1310  710690                          Ølgod      30
# 1311  708972                        Blåvand      19
# 1312  704694                        Agerbæk      23
# 1313  701482                        Ansager      32
#
#                            afstemningssted_navn  kommune_id  \
# 0                      Svindinge Forsamlingshus         450
# 1                                 Nymarksskolen         440
# 2                       Kerteminde Idrætscenter         440
# 3                      Skellerup Forsamlingshus         450
# 4                                  Nyborghallen         450
# ...                                         ...         ...
# 1309                   Birgittegården, Rød Stue         573
# 1310  Ølgod Hallen - Bemærk NYT afstemningssted         573
# 1311                          Blåvand Borgerhus         573
# 1312                              Agerbæk Hotel         573
# 1313       Skovlund-Ansager Hallen, Mini-hallen         573
#
#       opstillingskreds_nummer opstillingskreds_dagi_id  \
# 0                          46                   403614
# 1                          46                   403614
# 2                          46                   403614
# 3                          46                   403614
# 4                          46                   403614
# ...                       ...                      ...
# 1309                       54                   403620
# 1310                       54                   403620
# 1311                       54                   403620
# 1312                       54                   403620
# 1313                       54                   403620
#
#                      afstemningssted_adresse kommune_navn  kommune_dagi_id
# 0           Strædet 2, Svindinge, 5853 Ørbæk       Nyborg           389160
# 1     Nymarken 47, Hundslev, 5300 Kerteminde   Kerteminde           389159
# 2                Enggade 19, 5300 Kerteminde   Kerteminde           389159
# 3         Skellerup Byvej 16, 5540 Ullerslev       Nyborg           389160
# 4                      Halvej 1, 5800 Nyborg       Nyborg           389160
# ...                                      ...          ...              ...
# 1309            Falkevej 4A, Sig, 6800 Varde        Varde           389173
# 1310                Skolegade 18, 6870 Ølgod        Varde           389173
# 1311            Blåvandvej 30A, 6857 Blåvand        Varde           389173
# 1312               Storegade 7, 6753 Agerbæk        Varde           389173
# 1313               Lærkevej 16, 6823 Ansager        Varde           389173
#
# [1314 rows x 10 columns]

# %%
# for each kommune dagi id generate a csv file with the afstemningssteder for that kommune
output_dir = 'data/struktureret/kv/valgresultater/afstemningssteder/'

os.makedirs(output_dir, exist_ok=True)

num = 0
for kommune_id, group in df_afstemningssteder.groupby('kommune_id'):
    kommune_navn = group['kommune_navn'].iloc[0].lower().replace(' ', '_')
    output_file = os.path.join(output_dir, f'{kommune_id}_{kommune_navn}_afstemningsområde.csv')
    group['største_parti'] = ''  # placeholder column for største parti
    group.to_csv(output_file, index=False)
    num += 1
print(f'Wrote afstemningssteder for {num} kommuner to {output_dir}')
# Out:
# Wrote afstemningssteder for 98 kommuner to data/struktureret/kv/valgresultater/afstemningssteder/

# %%
# also generate a file for each kommune in the folder data/struktureret/kv/valgresultater/kommune/
output_dir_kommune = 'data/struktureret/kv/valgresultater/kommune/'

os.makedirs(output_dir_kommune, exist_ok=True)
# the file should have the columns: kommune_id, kommune_dagi_id, kommune_navn, parti, procent_25, stemmer_25, procent_21, stemmer_21

for kommune_id, group in df_afstemningssteder.groupby('kommune_id'):
    kommune_navn = group['kommune_navn'].iloc[0].lower().replace(' ', '_')
    kommune_dagi_id = group['kommune_dagi_id'].iloc[0]
    output_file = os.path.join(output_dir_kommune, f'{kommune_id}_{kommune_navn}_kommune.csv')
    df_kommune = pd.DataFrame([{
        'kommune_id': kommune_id,
        'kommune_dagi_id': kommune_dagi_id,
        'kommune_navn': group['kommune_navn'].iloc[0],
        'partier': '',
        'procent_25': '',
        'stemmer_25': '',
        'procent_21': '',
        'stemmer_21': ''
    }])
    df_kommune.to_csv(output_file, index=False)

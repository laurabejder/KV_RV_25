# %%
import pandas as pd
import paramiko
import os
import re
import json

# %%
# loop over all the files in data/struktureret/kv/valgresultater/kommuner 

files = os.listdir("data/struktureret/kv/valgresultater/kommune")
for file in files:
    # only keep the columns partier,procent_25,procent_21
    df = pd.read_csv(f"data/struktureret/kv/valgresultater/kommune/{file}")
    # only keep the columns partier,procent_25,procent_21   
    df = df[["partier","procent_25","procent_21"]]
    df.to_csv(f"data/struktureret/kv/valgresultater/kommune/{file}", index=False)

# %%
# load in all the csv files in data/kv21_resultater folder
path = "data/21_resultater/kv21_raw"

parti_info = json.load(open("data/partier.json"))
kommune_info = json.load(open("data/kommuner.json"))

parti_info = [parti for parti in parti_info if parti["listebogstav"] != "Æ" and parti["listebogstav"] != "M"]

super_df = pd.DataFrame()

csv_files = [os.path.join(path, file) for file in os.listdir(path) if file.endswith(".csv")]
for file in csv_files:
    df = pd.read_csv(file, sep=";")
    print(file)

    total_votes = df["Stemmetal"].sum()

    df = df.groupby(["Bogstavbetegnelse","Listenavn"]).agg({"Stemmetal":"sum"}).reset_index().sort_values(by="Stemmetal", ascending=False)
    df["Procent"] = df["Stemmetal"] / total_votes * 100

    def get_standard_party_name(row):
        key = str(row["Bogstavbetegnelse"]).strip().upper()
        for parti in parti_info:                  # ensure parti_info is a list of dicts
            if key == str(parti["listebogstav"]).strip().upper():
                # return standardized (name, bogstav)
                return parti["navn"], parti["bogstav"]
        # fallback: keep original values, but return a pair
        return row["Listenavn"], row["Bogstavbetegnelse"]

    df[["Listenavn", "bogstav"]] = df.apply(get_standard_party_name, axis=1, result_type="expand")  

    # get the kommune name from the file name by grabbing the part between the second and third underscore
    df['kommune_navn'] = file.split("_")[4]
    df['kommune_id'] = None
    df['kommune_dagi_id'] = None

    # get the kommune_id and the dagi_ud from kommune_info json
    for kommune in kommune_info:
        if kommune["kommune_navn"].lower() == df['kommune_navn'].iloc[0].lower():
            df['kommune_id'] = kommune["kommune_id"]
            df['kommune_dagi_id'] = kommune["kommune_dagi_id"]
            break


    #rename and reorder the columns: 
    #kommune_id,kommune_dagi_id,kommune_navn,listebogstav,partier,bogstav,procent_25,stemmer_25
    df = df[["kommune_id","kommune_dagi_id","kommune_navn","Bogstavbetegnelse","Listenavn","bogstav","Procent","Stemmetal"]]
    df.columns = ["kommune_id","kommune_dagi_id","kommune_navn","listebogstav","partier","bogstav","procent_21","stemmer_21"]

    super_df = pd.concat([super_df, df], ignore_index=True)
super_df
super_df.to_csv("data/21_resultater/kv21_parti_resultater.csv", index=False)
# Out:
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Aarhus_06-11-2025 9.44.23.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Lolland_06-11-2025 9.38.35.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Tårnby_06-11-2025 9.43.8.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Tønder_06-11-2025 9.43.3.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Struer_06-11-2025 9.42.21.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Lejre_06-11-2025 9.38.23.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ishøj_06-11-2025 9.37.18.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Kerteminde_06-11-2025 9.37.48.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Herlev_06-11-2025 9.34.33.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Albertslund_06-11-2025 9.29.31.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Brøndby_06-11-2025 9.30.46.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Dragør_06-11-2025 9.31.10.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Helsingør_06-11-2025 9.34.27.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_København_06-11-2025 9.38.5.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Norddjurs_06-11-2025 9.39.20.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Høje-Taastrup_06-11-2025 9.35.51.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Vordingborg_06-11-2025 9.43.59.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Mariagerfjord_06-11-2025 9.39.1.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Silkeborg_06-11-2025 9.41.23.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Vesthimmerlands_06-11-2025 9.43.46.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Odder_06-11-2025 9.40.1.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Samsø_06-11-2025 9.41.17.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Hørsholm_06-11-2025 9.37.5.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Nordfyns_06-11-2025 9.39.33.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Nyborg_06-11-2025 9.39.40.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Vallensbæk_06-11-2025 9.43.18.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Aabenraa_06-11-2025 9.44.10.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Brønderslev_06-11-2025 9.30.51.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Gentofte_06-11-2025 9.33.33.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Jammerbugt_06-11-2025 9.37.24.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Bornholm_06-11-2025 9.30.41.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Morsø_06-11-2025 9.39.13.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Lemvig_06-11-2025 9.38.28.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Sønderborg_06-11-2025 9.42.43.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Solrød_06-11-2025 9.42.1.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Holbæk_06-11-2025 9.35.28.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ringkøbing-Skjern_06-11-2025 9.40.41.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Frederikshavn_06-11-2025 9.33.6.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Vejle_06-11-2025 9.43.40.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Egedal_06-11-2025 9.31.17.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Furesø_06-11-2025 9.33.17.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Slagelse_06-11-2025 9.41.43.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Hillerød_06-11-2025 9.34.44.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Hjørring_06-11-2025 9.35.23.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Frederiksberg_06-11-2025 9.32.54.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Fanø_06-11-2025 9.31.39.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Guldborgsund_06-11-2025 9.34.1.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Sorø_06-11-2025 9.42.7.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Greve_06-11-2025 9.33.51.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ikast-Brande_06-11-2025 9.37.12.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Fredericia_06-11-2025 9.32.7.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Svendborg_06-11-2025 9.42.27.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Rebild_06-11-2025 9.40.31.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Lyngby-Taarbæk_06-11-2025 9.38.51.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Thisted_06-11-2025 9.42.56.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ringsted_06-11-2025 9.40.47.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Syddjurs_06-11-2025 9.42.37.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Langeland_06-11-2025 9.38.16.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Vejen_06-11-2025 9.43.35.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Kolding_06-11-2025 9.37.58.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Glostrup_06-11-2025 9.33.45.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Stevns_06-11-2025 9.42.15.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Læsø_06-11-2025 9.38.56.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Odense_06-11-2025 9.40.7.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Billund_06-11-2025 9.30.37.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Holstebro_06-11-2025 9.35.32.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Fredensborg_06-11-2025 9.31.58.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Skive_06-11-2025 9.41.35.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Haderslev_06-11-2025 9.34.6.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Odsherred_06-11-2025 9.40.18.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Skanderborg_06-11-2025 9.41.29.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Hedensted_06-11-2025 9.34.20.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Randers_06-11-2025 9.40.23.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Frederikssund_06-11-2025 9.33.12.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Horsens_06-11-2025 9.35.37.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Halsnæs_06-11-2025 9.34.11.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Næstved_06-11-2025 9.39.46.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Faaborg-Midtfyn_06-11-2025 9.33.24.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Hvidovre_06-11-2025 9.35.43.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Gribskov_06-11-2025 9.33.55.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Køge_06-11-2025 9.38.11.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Esbjerg_06-11-2025 9.31.33.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Viborg_06-11-2025 9.43.52.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Faxe_06-11-2025 9.31.51.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Rudersdal_06-11-2025 9.41.1.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Allerød_06-11-2025 9.30.7.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Roskilde_06-11-2025 9.40.54.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Assens_06-11-2025 9.30.13.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Aalborg_06-11-2025 9.44.14.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ærø_06-11-2025 9.44.5.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Varde_06-11-2025 9.43.25.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Herning_06-11-2025 9.34.39.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Ballerup_06-11-2025 9.30.20.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Gladsaxe_06-11-2025 9.33.39.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Middelfart_06-11-2025 9.39.8.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Kalundborg_06-11-2025 9.37.29.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Rødovre_06-11-2025 9.41.10.csv
# data/21_resultater/kv21_raw/Kommunalvalg_2021_Favrskov_06-11-2025 9.31.43.csv

# %%
# load in all the csv files in data/kv21_resultater folde
path = "data/21_resultater/rv21_raw"
parti_info = json.load(open("data/partier.json"))
super_df = pd.DataFrame()

# In parti_info, drop the entry where listebogstav is "Æ" or M
parti_info = [parti for parti in parti_info if parti["listebogstav"] != "Æ" and parti["listebogstav"] != "M"]


csv_files = [os.path.join(path, file) for file in os.listdir(path) if file.endswith(".csv")]
for file in csv_files:
    print(f"Processing file: {file}")
    df = pd.read_csv(file, sep=";")


    total_votes = df["Stemmetal"].sum()

    df = df.groupby(["Bogstavbetegnelse","Listenavn"]).agg({"Stemmetal":"sum"}).reset_index().sort_values(by="Stemmetal", ascending=False)
    df["Procent"] = df["Stemmetal"] / total_votes * 100

    def get_standard_party_name(row):
        key = str(row["Bogstavbetegnelse"]).strip().upper()
        for parti in parti_info:   
            if key == str(parti["listebogstav"]).strip().upper():
                print(f"Mapping {key} to {parti['navn']} ({parti['bogstav']})")
                 # return standardized (name, bogstav)
                return parti["navn"], parti["bogstav"]
         # fallback: keep original values, but return a pair
        return row["Listenavn"], row["Bogstavbetegnelse"]

    df[["Listenavn", "bogstav"]] = df.apply(get_standard_party_name, axis=1, result_type="expand")  

    df['region_navn'] = file.split("_")[4]

    super_df = pd.concat([super_df, df], ignore_index=True)
super_df

super_df.to_csv("data/21_resultater/rv21_parti_resultater.csv", index=False)
# Out:
# Processing file: data/21_resultater/rv21_raw/Regionsrådsvalg_2021_Region Midtjylland_11-11-2025 10.20.9.csv
# Mapping A to Socialdemokratiet (S)
# Mapping V to Venstre (V)
# Mapping C to Konservative (K)
# Mapping F to SF (SF)
# Mapping Ø to Enhedslisten (EL)
# Mapping B to Radikale (R)
# Mapping O to Dansk Folkeparti (DF)
# Mapping K to Kristendemokraterne (KD)
# Mapping I to Liberal Alliance (LA)
# Mapping Å to Alternativet (ALT)
# Processing file: data/21_resultater/rv21_raw/Regionsrådsvalg_2021_Region Syddanmark_11-11-2025 10.20.22.csv
# Mapping V to Venstre (V)
# Mapping A to Socialdemokratiet (S)
# Mapping C to Konservative (K)
# Mapping F to SF (SF)
# Mapping Ø to Enhedslisten (EL)
# Mapping O to Dansk Folkeparti (DF)
# Mapping B to Radikale (R)
# Mapping I to Liberal Alliance (LA)
# Mapping K to Kristendemokraterne (KD)
# Mapping Å to Alternativet (ALT)
# Processing file: data/21_resultater/rv21_raw/Regionsrådsvalg_2021_Region Nordjylland_11-11-2025 10.20.15.csv
# Mapping A to Socialdemokratiet (S)
# Mapping V to Venstre (V)
# Mapping C to Konservative (K)
# Mapping Ø to Enhedslisten (EL)
# Mapping F to SF (SF)
# Mapping O to Dansk Folkeparti (DF)
# Mapping B to Radikale (R)
# Mapping I to Liberal Alliance (LA)
# Mapping K to Kristendemokraterne (KD)
# Mapping Å to Alternativet (ALT)

# %%
# # find the corresponding kommune_id and kommune_dagi_id from kommune_info
# for index, row in super_df.iterrows():
#     kommune_navn = row["kommune_navn"]
#     for kommune in kommune_info:
#         if kommune_navn.lower() == kommune["kommune_navn"].lower():
#             super_df.at[index, "kommune_id"] = kommune["kommune_id"]
#             super_df.at[index, "kommune_dagi_id"] = kommune["kommune_dagi_id"]
#             break

# %%
# super_df
# Out:
#      kommune_id kommune_dagi_id kommune_navn listebogstav  \
# 0           751          389194       Aarhus            A
# 1           751          389194       Aarhus            C
# 2           751          389194       Aarhus            F
# 3           751          389194       Aarhus            V
# 4           751          389194       Aarhus            Ø
# ...         ...             ...          ...          ...
# 1113        710          389188     Favrskov            B
# 1114        710          389188     Favrskov            D
# 1115        710          389188     Favrskov            O
# 1116        710          389188     Favrskov            L
# 1117        710          389188     Favrskov            I
#
#                        partier bogstav  procent_21  stemmer_21
# 0            Socialdemokratiet       S   28.739157       55295
# 1                 Konservative       K   14.592808       28077
# 2                           SF      SF   13.741470       26439
# 3                      Venstre       V   11.868318       22835
# 4                 Enhedslisten      EL    9.897975       19044
# ...                        ...     ...         ...         ...
# 1113                  Radikale       R    3.781591        1007
# 1114            Nye Borgerlige       D    3.537497         942
# 1115          Dansk Folkeparti      DF    3.511210         935
# 1116  Samlingspartiet Favrskov       L    1.186676         316
# 1117          Liberal Alliance      LA    0.897518         239
#
# [1118 rows x 8 columns]

# %%
#super_df.to_csv("data/kv21_resultater/parti_resultater.csv", index=False)

# %%
# FTP login information
host = "data.valg.dk"
port = 22
username = "Valg"
password = "Valg"

# Forbindelse til FTP-server
transport = paramiko.Transport((host, port))
transport.connect(username=username, password=password)
sftp = paramiko.SFTPClient.from_transport(transport)

# %%
sftp.listdir('data/regionsrådsvalg-134-18-11-2025/geografi')
# Out:
# ['Opstillingskreds-311020251900.json.hash',
#  'Storkreds-311020251900.json.hash',
#  'Storkreds-311020251900.json',
#  'Valglandsdel-311020251900.json.hash',
#  'Valglandsdel-311020251900.json',
#  'Region-311020251900.json.hash',
#  'Region-311020251900.json',
#  'Kommune-311020251900.json.hash',
#  'Kommune-311020251900.json',
#  'Afstemningsomraade-311020251900.json.hash',
#  'Afstemningsomraade-311020251900.json',
#  'Opstillingskreds-311020251900.json']

# %%
with sftp.open('data/regionsrådsvalg-134-18-11-2025/verifikation/valgresultater/valgresultater-Regionsrådsvalg-Københavns_Kommune-3__Nordvest-190820250843.json') as f:
    text = f.read().decode('latin-1')  # or 'windows-1252'
    data = json.loads(text)

# %%
data
# Out:
# {'Valgdag': '18-11-2025',
#  'Valgart': 'RegionsrÃ¥dsvalg',
#  'FrigivelsesTidspunktUTC': '19-08-2025 06:43:57',
#  'Storkreds': 'KÃ¸benhavn',
#  'Storkredsnummer': 1,
#  'Opstillingskreds': 'Ã\x98sterbro',
#  'OpstillingskredsDagiId': 1,
#  'Kommune': 'KÃ¸benhavn',
#  'Kommunekode': 101,
#  'AfstemningsomrÃ¥deNummer': 6,
#  'AfstemningsomrÃ¥deDagiId': 706166,
#  'AfstemningsomrÃ¥de': '3. Nordvest',
#  'UgyldigeFremmÃ¸dteStemmerÃ\x85rsager': [],
#  'UgyldigeBrevstemmerÃ\x85rsager': [],
#  'Resultatart': 'IngenResultater',
#  'AfgivneStemmer': 0,
#  'GyldigeStemmer': 0,
#  'UgyldigeStemmerUdoverBlanke': 0,
#  'BlankeUgyldigeFremmÃ¸dteStemmer': 0,
#  'BlankeUgyldigeBrevstemmer': 0,
#  'AfgivneStemmerDifferenceFraForrigeValg': None,
#  'GyldigeStemmerDifferenceFraForrigeValg': None,
#  'UgyldigeStemmerDifferenceFraForrigeValg': None,
#  'BlankeStemmerDifferenceFraForrigeValg': None,
#  'AntalStemmeberettigedeVÃ¦lgereDifferenceFraForrigeValg': None,
#  'AntalStemmeberettigedeVÃ¦lgere': 40000}

# %%
with sftp.open('data/regionsrådsvalg-134-18-11-2025/geografi/Afstemningsomraade-311020251900.json') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709812',
#   'Nummer': 5,
#   'Navn': 'Langå, Svindinge Og Øksendrup',
#   'Afstemningssted': {'Navn': 'Svindinge Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-ffec-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Strædet 2, Svindinge, 5853 Ørbæk'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '748590',
#   'Nummer': 3,
#   'Navn': 'Nymarken',
#   'Afstemningssted': {'Navn': 'Nymarksskolen',
#    'Adgangsadresse': {'Id': '0a3f5088-6fcb-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nymarken 47, Hundslev, 5300 Kerteminde'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706574',
#   'Nummer': 2,
#   'Navn': 'Kerteminde',
#   'Afstemningssted': {'Navn': 'Kerteminde Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f5088-62f6-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Enggade 19, 5300 Kerteminde'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703760',
#   'Nummer': 8,
#   'Navn': 'Skellerup',
#   'Afstemningssted': {'Navn': 'Skellerup Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-dbab-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skellerup Byvej 16, 5540 Ullerslev'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703754',
#   'Nummer': 2,
#   'Navn': 'Nyborghallen',
#   'Afstemningssted': {'Navn': 'Nyborghallen',
#    'Adgangsadresse': {'Id': '0a3f5088-c9ba-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Halvej 1, 5800 Nyborg'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708346',
#   'Nummer': 10,
#   'Navn': 'Ørbæk',
#   'Afstemningssted': {'Navn': 'Ørbæk Midtpunkt',
#    'Adgangsadresse': {'Id': '0a3f508a-fa46-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Langemosevej 5, 5853 Ørbæk'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712260',
#   'Nummer': 1,
#   'Navn': 'Hindsholm',
#   'Afstemningssted': {'Navn': 'Hindsholmskolen',
#    'Adgangsadresse': {'Id': '0a3f5088-6195-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Dalby Bygade 5, 5380 Dalby'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708334',
#   'Nummer': 6,
#   'Navn': 'Ullerslev',
#   'Afstemningssted': {'Navn': 'Ullerslev Kultur- og Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f508a-dbe4-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skolevej 2, 5540 Ullerslev'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705368',
#   'Nummer': 1,
#   'Navn': 'Aunslevhallen',
#   'Afstemningssted': {'Navn': 'Aunslevhallen',
#    'Adgangsadresse': {'Id': '0a3f5088-d83c-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skovgyden 1, Aunslev, 5800 Nyborg'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706642',
#   'Nummer': 13,
#   'Navn': 'Kullerup Og Refsvindinge',
#   'Afstemningssted': {'Navn': 'Refsvindinge Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-fd91-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Refsvindinge Byvej 26, Refsvindinge, 5853 Ørbæk'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705374',
#   'Nummer': 4,
#   'Navn': 'Vindinge Forsamlingshus',
#   'Afstemningssted': {'Navn': 'Vindinge Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5088-c387-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bøjdenvej 75, Vindinge, 5800 Nyborg'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708340',
#   'Nummer': 9,
#   'Navn': 'Langtved',
#   'Afstemningssted': {'Navn': 'Langtved Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-d976-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Langtvedvej 15, 5540 Ullerslev'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705322',
#   'Nummer': 4,
#   'Navn': 'Marslev',
#   'Afstemningssted': {'Navn': 'Marslev Skole- og Børnehus',
#    'Adgangsadresse': {'Id': '0a3f5088-8009-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Marslev Byvej 41, 5290 Marslev'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707976',
#   'Nummer': 6,
#   'Navn': 'Munkebo',
#   'Afstemningssted': {'Navn': 'Munkebo Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f5088-ba7f-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Mosevangen 2, 5330 Munkebo'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705316',
#   'Nummer': 5,
#   'Navn': 'Langeskov',
#   'Afstemningssted': {'Navn': 'Langeskov Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f5088-7b4d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Børmosevej 3, 5550 Langeskov'}},
#   'Kommunekode': 440,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701998',
#   'Nummer': 7,
#   'Navn': 'Ellinge',
#   'Afstemningssted': {'Navn': 'Ellinge Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-d695-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gl. Byvej 12, Ellinge, 5540 Ullerslev'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702004',
#   'Nummer': 12,
#   'Navn': 'Ellested Og Herrested',
#   'Afstemningssted': {'Navn': 'Herrested Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-fd24-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Odensevej 100, Herrested, 5853 Ørbæk'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706634',
#   'Nummer': 3,
#   'Navn': 'Bastionen',
#   'Afstemningssted': {'Navn': 'Bastionen',
#    'Adgangsadresse': {'Id': '0a3f5088-d3ac-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nørrevoldgade 63, 5800 Nyborg'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705380',
#   'Nummer': 11,
#   'Navn': 'Frørup Og Tårup',
#   'Afstemningssted': {'Navn': 'Frørup Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f508a-f991-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Kogsbøllevej 83, 5871 Frørup'}},
#   'Kommunekode': 450,
#   'Opstillingskredsnummer': 46,
#   'Opstillingskreds_Dagi_id': '403614',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703930',
#   'Nummer': 2,
#   'Navn': 'Brande',
#   'Afstemningssted': {'Navn': 'Brande Hallerne',
#    'Adgangsadresse': {'Id': '0a3f5091-1599-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ole Bendix Vej 1, 7330 Brande'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705552',
#   'Nummer': 1,
#   'Navn': 'Bording',
#   'Afstemningssted': {'Navn': 'Bording Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5092-1f0b-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'J Christensens Plads 10, 7441 Bording'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709984',
#   'Nummer': 3,
#   'Navn': 'Ejstrupholm',
#   'Afstemningssted': {'Navn': 'Ejstrupholm Hallen',
#    'Adgangsadresse': {'Id': '0a3f5090-83c8-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Vestergade 38B, 7361 Ejstrupholm'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '713316',
#   'Nummer': 4,
#   'Navn': 'Engesvang',
#   'Afstemningssted': {'Navn': 'Engesvang Hallen',
#    'Adgangsadresse': {'Id': '0a3f5092-0387-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Dybdalsvej 3, 7442 Engesvang'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702176',
#   'Nummer': 5,
#   'Navn': 'Ikast',
#   'Afstemningssted': {'Navn': 'Sportscenter Ikast',
#    'Adgangsadresse': {'Id': '0a3f5092-1c43-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Stadion Alle 2B, 7430 Ikast'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '713298',
#   'Nummer': 6,
#   'Navn': 'Nørre Snede',
#   'Afstemningssted': {'Navn': 'Nørre Snede Hallen',
#    'Adgangsadresse': {'Id': '0a3f5090-804a-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skolegade 16B, 8766 Nørre Snede'}},
#   'Kommunekode': 756,
#   'Opstillingskredsnummer': 79,
#   'Opstillingskreds_Dagi_id': '403600',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706292',
#   'Nummer': 2,
#   'Navn': 'Arnborg',
#   'Afstemningssted': {'Navn': 'Arnborg Hallen',
#    'Adgangsadresse': {'Id': '0a3f5091-834e-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Sportsvej 18, Arnborg, 7400 Herning'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712062',
#   'Nummer': 1,
#   'Navn': 'Herning',
#   'Afstemningssted': {'Navn': 'Kongrescentret',
#    'Adgangsadresse': {'Id': '0a3f5091-97e7-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Østergade 37, 7400 Herning'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703462',
#   'Nummer': 5,
#   'Navn': 'Kibæk',
#   'Afstemningssted': {'Navn': 'Kibæk Krydsfelt Gl. Hal',
#    'Adgangsadresse': {'Id': '0a3f5093-214e-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Velhustedvej 12, 6933 Kibæk'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710918',
#   'Nummer': 9,
#   'Navn': 'Skarrild',
#   'Afstemningssted': {'Navn': 'Skarrild Karstoft Kultur og Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f5093-1f44-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skolevejen 6, Skarrild, 6933 Kibæk'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701670',
#   'Nummer': 6,
#   'Navn': 'Kølkær',
#   'Afstemningssted': {'Navn': 'Kølkær Selskabslokaler',
#    'Adgangsadresse': {'Id': '0a3f5091-71ec-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nørlundvej 2, Kølkær, 7400 Herning'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704992',
#   'Nummer': 11,
#   'Navn': 'Studsgård',
#   'Afstemningssted': {'Navn': 'Studsgård Minihal',
#    'Adgangsadresse': {'Id': '0a3f5091-6be0-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Momhøjvej 36A, Studsgård, 7400 Herning'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701664',
#   'Nummer': 8,
#   'Navn': 'Sdr. Felding',
#   'Afstemningssted': {'Navn': 'Sdr. Felding Hallen',
#    'Adgangsadresse': {'Id': '78d0c301-ae1d-6373-e044-00144f3ead67',
#     'Adressebetegnelse': 'Lupinvænget 2, 7280 Sønder Felding'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712050',
#   'Nummer': 7,
#   'Navn': 'Lind',
#   'Afstemningssted': {'Navn': 'ALPI Hallerne',
#    'Adgangsadresse': {'Id': '0a3f5091-61ae-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Kollundvej 33, Lind, 7400 Herning'}},
#   'Kommunekode': 657,
#   'Opstillingskredsnummer': 80,
#   'Opstillingskreds_Dagi_id': '403590',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705404',
#   'Nummer': 4,
#   'Navn': 'Lynge',
#   'Afstemningssted': {'Navn': 'Lynge Idrætsanlæg - Hal 2',
#    'Adgangsadresse': {'Id': '0a3f507e-4d41-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Idrætsvej 14, 3540 Lynge'}},
#   'Kommunekode': 201,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704274',
#   'Nummer': 3,
#   'Navn': 'Nærum',
#   'Afstemningssted': {'Navn': 'Ravnholm Skole, afdeling Nærum',
#    'Adgangsadresse': {'Id': '7096f618-6248-5ed1-e044-00144f3ead67',
#     'Adressebetegnelse': 'Fruerlund 9, 2850 Nærum'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711588',
#   'Nummer': 1,
#   'Navn': 'Birkerød',
#   'Afstemningssted': {'Navn': 'Birkerød Skole',
#    'Adgangsadresse': {'Id': '3e704ca9-a833-3598-e044-0003ba298018',
#     'Adressebetegnelse': 'Birkerød Parkvej 12, 3460 Birkerød'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702734',
#   'Nummer': 4,
#   'Navn': 'Sjælsø',
#   'Afstemningssted': {'Navn': 'Rude Skov Skole, afdeling Sjælsø',
#    'Adgangsadresse': {'Id': '0a3f507e-79d5-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ravnsnæsvej 120, 3460 Birkerød'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703802',
#   'Nummer': 2,
#   'Navn': 'Skovvang',
#   'Afstemningssted': {'Navn': 'Lillevang Skole - Afd. Skovvang',
#    'Adgangsadresse': {'Id': '0a3f507e-57d1-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Poppelvej 1A, 3450 Allerød'}},
#   'Kommunekode': 201,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707194',
#   'Nummer': 7,
#   'Navn': 'Trørød',
#   'Afstemningssted': {'Navn': 'Trørødskolen',
#    'Adgangsadresse': {'Id': '0a3f507d-aa2e-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gammel Holtevej 2, Gl Holte, 2950 Vedbæk'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711248',
#   'Nummer': 1,
#   'Navn': 'Blovstrød',
#   'Afstemningssted': {'Navn': 'Blovstrød Skole',
#    'Adgangsadresse': {'Id': '0a3f507e-4ff0-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Kærvej 10, 3450 Allerød'}},
#   'Kommunekode': 201,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705784',
#   'Nummer': 6,
#   'Navn': 'Toftevang',
#   'Afstemningssted': {'Navn': 'Søholmskolen, afdeling Toftevang',
#    'Adgangsadresse': {'Id': '0a3f507e-7fe4-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Teglporten 7, 3460 Birkerød'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706698',
#   'Nummer': 3,
#   'Navn': 'Lillerød',
#   'Afstemningssted': {'Navn': 'Lillevang Skole - Afd. Lillerød',
#    'Adgangsadresse': {'Id': '0a3f507e-48fb-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Frederiksborgvej 65, 3450 Allerød'}},
#   'Kommunekode': 201,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701142',
#   'Nummer': 9,
#   'Navn': 'Vedbæk',
#   'Afstemningssted': {'Navn': 'Vedbæk Skole',
#    'Adgangsadresse': {'Id': '0a3f507d-ad93-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Henriksholms Alle 2, 2950 Vedbæk'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702728',
#   'Nummer': 5,
#   'Navn': 'Skovly',
#   'Afstemningssted': {'Navn': 'Skovlyskolen',
#    'Adgangsadresse': {'Id': '0a3f507d-a210-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Borgm.Schneiders Vej 40, Øverød, 2840 Holte'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705398',
#   'Nummer': 5,
#   'Navn': 'Ravnsholt',
#   'Afstemningssted': {'Navn': 'Ravnsholtshallen',
#    'Adgangsadresse': {'Id': '0a3f507e-5ee1-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Søparken 1, 3450 Allerød'}},
#   'Kommunekode': 201,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '748890',
#   'Nummer': 2,
#   'Navn': 'Grünersvej',
#   'Afstemningssted': {'Navn': 'Holte Skole, afdeling Grünersvej',
#    'Adgangsadresse': {'Id': '0a3f507d-ab88-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Grünersvej 6, 2840 Holte'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708708',
#   'Nummer': 8,
#   'Navn': 'Vangebo',
#   'Afstemningssted': {'Navn': 'Ravnholm Skole, afdeling Vangebo',
#    'Adgangsadresse': {'Id': '0a3f507d-c45d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Vangeboled 9, Søllerød, 2840 Holte'}},
#   'Kommunekode': 230,
#   'Opstillingskredsnummer': 26,
#   'Opstillingskreds_Dagi_id': '403577',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708426',
#   'Nummer': 1,
#   'Navn': 'Errindlev',
#   'Afstemningssted': {'Navn': 'Errindlev Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5085-3bd2-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Centralskolevej 8, 4895 Errindlev'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709912',
#   'Nummer': 14,
#   'Navn': 'Askø',
#   'Afstemningssted': {'Navn': 'Askø Skole',
#    'Adgangsadresse': {'Id': '0a3f5085-69c0-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Askø Skolevej 8, 4942 Askø'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706762',
#   'Nummer': 8,
#   'Navn': 'Sandby',
#   'Afstemningssted': {'Navn': 'Sandby Kulturhus',
#    'Adgangsadresse': {'Id': '0a3f5086-7ed2-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Tårsvej 92, 4912 Harpelunde'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '700840',
#   'Nummer': 3,
#   'Navn': 'Holeby',
#   'Afstemningssted': {'Navn': 'Holeby Medborgerhus, Gymnastiksalen',
#    'Adgangsadresse': {'Id': '58910400-b8f1-44bf-8293-7420ee1595a8',
#     'Adressebetegnelse': 'Maribovej 1, 4960 Holeby'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705484',
#   'Nummer': 13,
#   'Navn': 'Maribo',
#   'Afstemningssted': {'Navn': 'Maribo Hallerne - Hal 2',
#    'Adgangsadresse': {'Id': '0a3f5085-7d0d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ved Stadion 4, 4930 Maribo'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708456',
#   'Nummer': 19,
#   'Navn': 'Østofte',
#   'Afstemningssted': {'Navn': 'Østofte Hallen',
#    'Adgangsadresse': {'Id': '0a3f5085-8024-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Østofte Gade 42, 4951 Nørreballe'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703882',
#   'Nummer': 37,
#   'Navn': 'Rødbyhavn',
#   'Afstemningssted': {'Navn': 'Rødbyhavn Sportshal, Gymnastiksalen',
#    'Adgangsadresse': {'Id': '0a3f5086-97f7-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Havnegade 101, 4970 Rødby'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706808',
#   'Nummer': 26,
#   'Navn': 'Birket',
#   'Afstemningssted': {'Navn': 'Signe Stubs Sognegård',
#    'Adgangsadresse': {'Id': '0a3f5086-71fa-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bandholmvej 79, 4943 Torrig L'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703864',
#   'Nummer': 29,
#   'Navn': 'Horslunde',
#   'Afstemningssted': {'Navn': 'Ravnsborghallen, Kulturhuset',
#    'Adgangsadresse': {'Id': '0a3f5086-7b1e-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Pederstrupvej 30, 4913 Horslunde'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706822',
#   'Nummer': 11,
#   'Navn': 'Søllested',
#   'Afstemningssted': {'Navn': 'Højrebyhallen',
#    'Adgangsadresse': {'Id': '0a3f5085-53f3-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bøgevej 2, 4920 Søllested'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709900',
#   'Nummer': 27,
#   'Navn': 'Fejø',
#   'Afstemningssted': {'Navn': 'Fejø Børne- og kulturhus',
#    'Adgangsadresse': {'Id': '0a3f5086-74e8-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Herredsvej 190, 4944 Fejø'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706746',
#   'Nummer': 35,
#   'Navn': 'Dannemare',
#   'Afstemningssted': {'Navn': 'Rudbjerghallen',
#    'Adgangsadresse': {'Id': '0a3f5086-8cf9-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Rudbjergvej 16B, 4983 Dannemare'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706816',
#   'Nummer': 28,
#   'Navn': 'Femø',
#   'Afstemningssted': {'Navn': 'Femø Kro og Kursuscenter',
#    'Adgangsadresse': {'Id': '0a3f5086-769f-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Askhavnsvej 69, 4945 Femø'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702106',
#   'Nummer': 36,
#   'Navn': 'Rødby',
#   'Afstemningssted': {'Navn': 'Blomsterparkens Cafeteria',
#    'Adgangsadresse': {'Id': 'bc5deabd-fcf4-4f86-b6e5-cb12c5327de1',
#     'Adressebetegnelse': 'Blomsterparken 70, 4970 Rødby'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': '27-08-2025 15:30:52',
#   'Dagi_id': '705458',
#   'Nummer': 20,
#   'Navn': 'Nakskov',
#   'Afstemningssted': {'Navn': 'Nakskov Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f5085-a4d1-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'A. E. Hansensvej 1, 4900 Nakskov'}},
#   'Kommunekode': 360,
#   'Opstillingskredsnummer': 29,
#   'Opstillingskreds_Dagi_id': '403639',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704018',
#   'Nummer': 56,
#   'Navn': 'Hallund',
#   'Afstemningssted': {'Navn': 'Hallund Kro',
#    'Adgangsadresse': {'Id': '0a3f5099-57da-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Sølvgade 74, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703190',
#   'Nummer': 10,
#   'Navn': 'Arentsminde',
#   'Afstemningssted': {'Navn': 'Arentsminde Cafeteria',
#    'Adgangsadresse': {'Id': '0a3f5099-344d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Thyvej 16, Arentsminde, 9460 Brovst'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '700990',
#   'Nummer': 5,
#   'Navn': 'Hjallerup',
#   'Afstemningssted': {'Navn': 'Hjallerup Kulturhus',
#    'Adgangsadresse': {'Id': '0a3f50c7-11ac-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nørre Alle 3A, 9320 Hjallerup'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704750',
#   'Nummer': 14,
#   'Navn': 'Thorup',
#   'Afstemningssted': {'Navn': 'Thorup Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5099-a9b3-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Toftholmvej 16, V Thorup, 9690 Fjerritslev'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707632',
#   'Nummer': 13,
#   'Navn': 'Fjerritslev',
#   'Afstemningssted': {'Navn': 'Idrætscenter Jammerbugt',
#    'Adgangsadresse': {'Id': '39ece5fb-f80f-0ee2-e044-0003ba298018',
#     'Adressebetegnelse': 'Brøndumvej 16B, 9690 Fjerritslev'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711454',
#   'Nummer': 70,
#   'Navn': 'Jerslev',
#   'Afstemningssted': {'Navn': 'Hallen på Toftegårdsskolen',
#    'Adgangsadresse': {'Id': 'a9435fb5-b505-49ba-8c80-202836fc063f',
#     'Adressebetegnelse': 'Sdr Ringgade 79, 9740 Jerslev J'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705646',
#   'Nummer': 50,
#   'Navn': 'Ø. Brønderslev',
#   'Afstemningssted': {'Navn': 'Samlingshuset',
#    'Adgangsadresse': {'Id': 'bdd77a9b-5e1b-4ff3-90e8-32ab232a6838',
#     'Adressebetegnelse': 'Elmevej 124, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710140',
#   'Nummer': 10,
#   'Navn': 'Brønderslev',
#   'Afstemningssted': {'Navn': 'Brønderslev Hallen',
#    'Adgangsadresse': {'Id': '0a3f5099-4997-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Knudsgade 15, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711896',
#   'Nummer': 4,
#   'Navn': 'Vedsted',
#   'Afstemningssted': {'Navn': 'Birkelse Hallen',
#    'Adgangsadresse': {'Id': '0a3f509c-0105-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gl. Landevej 62B, Birkelse, 9440 Aabybro'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710716',
#   'Nummer': 5,
#   'Navn': 'Gjøl',
#   'Afstemningssted': {'Navn': 'Gjøl Kro',
#    'Adgangsadresse': {'Id': '0a3f509c-0041-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Fjordgade 18, Gjøl, 9440 Aabybro'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '749357',
#   'Nummer': 7,
#   'Navn': 'V. Hjermitslev',
#   'Afstemningssted': {'Navn': 'Lunden',
#    'Adgangsadresse': {'Id': '0a3f509b-2620-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Assenbækvej 33, V. Hjermitslev, 9700 Brønderslev'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708630',
#   'Nummer': 80,
#   'Navn': 'Serritslev',
#   'Afstemningssted': {'Navn': 'Serritslev Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5099-46a0-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Hybenvej 3, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701514',
#   'Nummer': 20,
#   'Navn': 'Hune',
#   'Afstemningssted': {'Navn': 'Hune Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f509b-5438-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Vesterhavsvej 27, 9492 Blokhus'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704012',
#   'Nummer': 40,
#   'Navn': 'Thise',
#   'Afstemningssted': {'Navn': 'Manna-Thise Samlingshus',
#    'Adgangsadresse': {'Id': '0a3f5099-47dc-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Jens Thise Vej 33, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702304',
#   'Nummer': 34,
#   'Navn': 'Stenum',
#   'Afstemningssted': {'Navn': 'Stenum Kultur- og Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5099-5a86-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Tømmerbyvej 6, 9700 Brønderslev'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701540',
#   'Nummer': 3,
#   'Navn': 'Nørhalne',
#   'Afstemningssted': {'Navn': 'Nørhalne Hallen',
#    'Adgangsadresse': {'Id': '0a3f509c-0212-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gustav Zimmersvej 27, Nørhalne, 9430 Vadum'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704006',
#   'Nummer': 6,
#   'Navn': 'Klokkerholm',
#   'Afstemningssted': {'Navn': 'Klokkerholm Hallen',
#    'Adgangsadresse': {'Id': '0a3f5099-5fb9-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Anemonevej 5, Klokkerholm, 9320 Hjallerup'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '700996',
#   'Nummer': 4,
#   'Navn': 'Flauenskjold',
#   'Afstemningssted': {'Navn': 'Flauenskjold Kulturhus',
#    'Adgangsadresse': {'Id': '0a3f5099-7dfe-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ålborgvej 583, Flauenskjold, 9330 Dronninglund'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706102',
#   'Nummer': 9,
#   'Navn': 'Halvrimmen',
#   'Afstemningssted': {'Navn': 'Halvrimmen Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5099-2532-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Banevej 7, Halvrimmen, 9460 Brovst'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704764',
#   'Nummer': 18,
#   'Navn': 'Jetsmark',
#   'Afstemningssted': {'Navn': 'Jetsmark Idrætscenter',
#    'Adgangsadresse': {'Id': '0a3f509b-2a89-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bredgade 140, 9490 Pandrup'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707638',
#   'Nummer': 12,
#   'Navn': 'Skovsgård',
#   'Afstemningssted': {'Navn': 'Skovsgård Hotel',
#    'Adgangsadresse': {'Id': '0a3f5099-2a1f-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Hovedgaden 26, Skovsgård, 9460 Brovst'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709250',
#   'Nummer': 11,
#   'Navn': 'Tranum',
#   'Afstemningssted': {'Navn': 'Tranum Forsamlinghus',
#    'Adgangsadresse': {'Id': '0a3f5099-34b5-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Tranhøj 13, Tranum, 9460 Brovst'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703310',
#   'Nummer': 21,
#   'Navn': 'Saltum',
#   'Afstemningssted': {'Navn': 'Nolshallen',
#    'Adgangsadresse': {'Id': '0a3f509b-42ee-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nolsvej 1, 9493 Saltum'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708636',
#   'Nummer': 2,
#   'Navn': 'Asaa',
#   'Afstemningssted': {'Navn': 'Asaa-Hallen',
#    'Adgangsadresse': {'Id': '0a3f5099-6e32-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Møllehusvej 7, 9340 Asaa'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701500',
#   'Nummer': 2,
#   'Navn': 'Biersted',
#   'Afstemningssted': {'Navn': 'Biersted aktivitetscenter',
#    'Adgangsadresse': {'Id': '0a3f509c-0cb4-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Stationsvej 51, Biersted, 9440 Aabybro'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '749359',
#   'Nummer': 6,
#   'Navn': 'Ingstrup',
#   'Afstemningssted': {'Navn': 'Ingstrup Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f509b-5311-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Tværgade 11, Ingstrup, 9480 Løkken'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711858',
#   'Nummer': 8,
#   'Navn': 'Brovst',
#   'Afstemningssted': {'Navn': 'Sport og Kulturcenter',
#    'Adgangsadresse': {'Id': '0a3f5099-2661-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Damengvej 2, 9460 Brovst'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709280',
#   'Nummer': 1,
#   'Navn': 'Aabybro',
#   'Afstemningssted': {'Navn': 'DGI-Huset',
#    'Adgangsadresse': {'Id': '0a3f509c-045d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Jens Møllersvej 3, 9440 Aabybro'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705640',
#   'Nummer': 3,
#   'Navn': 'Dronninglund',
#   'Afstemningssted': {'Navn': 'Dronninglund Skole',
#    'Adgangsadresse': {'Id': '0a3f5099-71ea-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Rørholtvej 20, 9330 Dronninglund'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703196',
#   'Nummer': 16,
#   'Navn': 'Trekroner',
#   'Afstemningssted': {'Navn': 'Trekroner Landsbycenter',
#    'Adgangsadresse': {'Id': '362e6b23-5821-0f9b-e044-0003ba298018',
#     'Adressebetegnelse': 'Skolevænget 3B, Trekroner, 9690 Fjerritslev'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708624',
#   'Nummer': 1,
#   'Navn': 'Agersted',
#   'Afstemningssted': {'Navn': 'Rosendalcenteret',
#    'Adgangsadresse': {'Id': '0a3f5099-63cc-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Dronninglundvej 8, Agersted, 9330 Dronninglund'}},
#   'Kommunekode': 810,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '749358',
#   'Nummer': 15,
#   'Navn': 'Ørebro',
#   'Afstemningssted': {'Navn': 'Ørebroskolen',
#    'Adgangsadresse': {'Id': '0a3f5099-ab4e-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ørebrovej 128, Ørebro, 9690 Fjerritslev'}},
#   'Kommunekode': 849,
#   'Opstillingskredsnummer': 86,
#   'Opstillingskreds_Dagi_id': '403592',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712286',
#   'Nummer': 10,
#   'Navn': '2. Vest',
#   'Afstemningssted': {'Navn': 'Skolen på Islands Brygge',
#    'Adgangsadresse': {'Id': '0a3f507a-3e64-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Artillerivej 57, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '725346',
#   'Nummer': 57,
#   'Navn': '2. Øst',
#   'Afstemningssted': {'Navn': 'Dyvekeskolen',
#    'Adgangsadresse': {'Id': '0a3f507a-e16a-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Remisevej 16, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706166',
#   'Nummer': 8,
#   'Navn': '2. Nord',
#   'Afstemningssted': {'Navn': 'Amager Fælled Skole',
#    'Adgangsadresse': {'Id': '0a3f507b-05f2-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Sundholmsvej 2A, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711204',
#   'Nummer': 7,
#   'Navn': '2. Sundbyvester',
#   'Afstemningssted': {'Navn': 'Sundby Idrætspark',
#    'Adgangsadresse': {'Id': '0a3f507a-6784-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Englandsvej 61, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': '22-08-2025 18:00:41',
#   'Dagi_id': '706562',
#   'Nummer': 9,
#   'Navn': '2. Ørestad',
#   'Afstemningssted': {'Navn': 'Ørestad Gymnasium',
#    'Adgangsadresse': {'Id': '0a3f507b-3021-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ørestads Boulevard 75, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '22-08-2025 18:00:41',
#   'OpdateretUtc': None,
#   'Dagi_id': '749400',
#   'Nummer': 61,
#   'Navn': '2. Kalvebod Fælled',
#   'Afstemningssted': {'Navn': 'Kalvebod Fælled Skole',
#    'Adgangsadresse': {'Id': '32b79ac4-b50b-0587-e044-0003ba298018',
#     'Adressebetegnelse': 'Else Alfelts Vej 2, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '22-08-2025 18:00:41',
#   'OpdateretUtc': None,
#   'Dagi_id': '749401',
#   'Nummer': 62,
#   'Navn': '2. Peder Lykke',
#   'Afstemningssted': {'Navn': 'Peder Lykke Skolen',
#    'Adgangsadresse': {'Id': '81940255-aa10-49c4-98c5-1f7b5aa09bb2',
#     'Adressebetegnelse': 'Birketinget 3, 2300 København S'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 2,
#   'Opstillingskreds_Dagi_id': '403565',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701908',
#   'Nummer': 11,
#   'Navn': 'Dalby/Tved/Rebæk',
#   'Afstemningssted': {'Navn': 'Dalbyhallen',
#    'Adgangsadresse': {'Id': 'cdc69d57-fcdd-4248-bec6-34c07c258f0d',
#     'Adressebetegnelse': 'Dalbyvej 116C, Dalby, 6000 Kolding'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712326',
#   'Nummer': 14,
#   'Navn': 'Vamdrup/Hjarup/Ødis',
#   'Afstemningssted': {'Navn': 'Arena Syd',
#    'Adgangsadresse': {'Id': '0a3f5090-a167-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Idrætsvej 3, 6580 Vamdrup'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712312',
#   'Nummer': 15,
#   'Navn': 'Chr.Feld/Stepping/Taps/Hejls',
#   'Afstemningssted': {'Navn': 'Cuben',
#    'Adgangsadresse': {'Id': '0a3f508b-6775-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Østprøven 1, 6070 Christiansfeld'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701902',
#   'Nummer': 8,
#   'Navn': 'Centrum Syd',
#   'Afstemningssted': {'Navn': 'Brændkjærhallen, Idræts- og kulturhus',
#    'Adgangsadresse': {'Id': 'e5f076de-0008-4a43-86e5-314fe947e759',
#     'Adressebetegnelse': 'Dannersvej 2, 6000 Kolding'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '712320',
#   'Nummer': 10,
#   'Navn': 'Seest',
#   'Afstemningssted': {'Navn': 'Bakkeskolen',
#    'Adgangsadresse': {'Id': '0a3f5090-5441-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Seestvej 6, Seest, 6000 Kolding'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705308',
#   'Nummer': 12,
#   'Navn': 'S Bjert/S Stenderup/Vejstrup',
#   'Afstemningssted': {'Navn': 'Bjert-Hallen',
#    'Adgangsadresse': {'Id': '0a3f5090-239c-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Engløkke 7, Agtrup, 6091 Bjert'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701916',
#   'Nummer': 9,
#   'Navn': 'Sydbyen',
#   'Afstemningssted': {'Navn': 'Pulzion',
#    'Adgangsadresse': {'Id': '0a3f5090-4d4d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Peter Tofts Vej 21, 6000 Kolding'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707970',
#   'Nummer': 13,
#   'Navn': 'Vonsild',
#   'Afstemningssted': {'Navn': 'Vonsildhallen',
#    'Adgangsadresse': {'Id': '0a3f5090-1b1b-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Catolhavegyden 19, Vonsild, 6000 Kolding'}},
#   'Kommunekode': 621,
#   'Opstillingskredsnummer': 60,
#   'Opstillingskreds_Dagi_id': '403627',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '709628',
#   'Nummer': 10,
#   'Navn': 'Dybvad',
#   'Afstemningssted': {'Navn': 'Dybvadhallen',
#    'Adgangsadresse': {'Id': '6825e2c1-73ef-501c-e044-00144f3ead67',
#     'Adressebetegnelse': 'Ørnevej 8, 9352 Dybvad'}},
#   'Kommunekode': 813,
#   'Opstillingskredsnummer': 84,
#   'Opstillingskreds_Dagi_id': '403591',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
# ...
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708878',
#   'Nummer': 7,
#   'Navn': 'Tølløse',
#   'Afstemningssted': {'Navn': 'Tølløse Hallen',
#    'Adgangsadresse': {'Id': '0a3f5085-0d06-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Sportsvej 2, 4340 Tølløse'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708862',
#   'Nummer': 13,
#   'Navn': 'Svinninge',
#   'Afstemningssted': {'Navn': 'Svinninge Sportscenter',
#    'Adgangsadresse': {'Id': '0a3f5084-a1e4-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Svinningehallen 1, 4520 Svinninge'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707370',
#   'Nummer': 9,
#   'Navn': 'Regstrup',
#   'Afstemningssted': {'Navn': 'Jernløse Hallen',
#    'Adgangsadresse': {'Id': '0a3f5083-71d4-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gl. Skovvej 150B, Nørre Jernløse, 4420 Regstrup'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708890',
#   'Nummer': 1,
#   'Navn': 'Holbæk Øst',
#   'Afstemningssted': {'Navn': 'Bjergmarkshallen',
#    'Adgangsadresse': {'Id': '0a3f5083-1dbd-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bispehøjen 2, 4300 Holbæk'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704456',
#   'Nummer': 10,
#   'Navn': 'Undløse',
#   'Afstemningssted': {'Navn': 'Undløse Hallen',
#    'Adgangsadresse': {'Id': '0a3f5083-79ec-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Øvej 5A, Undløse, 4340 Tølløse'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710502',
#   'Nummer': 14,
#   'Navn': 'Gislinge',
#   'Afstemningssted': {'Navn': 'Gislinge Skole',
#    'Adgangsadresse': {'Id': '0a3f5084-a7dd-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skolevej 4, 4532 Gislinge'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707528',
#   'Nummer': 15,
#   'Navn': 'Orø',
#   'Afstemningssted': {'Navn': 'Orø Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5083-2013-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Brøndevej 24, Bybjerg, 4305 Orø'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702906',
#   'Nummer': 3,
#   'Navn': 'Holbæk Midt',
#   'Afstemningssted': {'Navn': 'Elværket',
#    'Adgangsadresse': {'Id': '56267bfc-4d7a-693c-e044-0003ba298018',
#     'Adressebetegnelse': 'Gasværksvej 9, 4300 Holbæk'}},
#   'Kommunekode': 316,
#   'Opstillingskredsnummer': 37,
#   'Opstillingskreds_Dagi_id': '403628',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706196',
#   'Nummer': 20,
#   'Navn': '5. Nørrebro',
#   'Afstemningssted': {'Navn': 'Guldberg Skole',
#    'Adgangsadresse': {'Id': '0a3f507a-f1f2-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Sjællandsgade 10, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710832',
#   'Nummer': 24,
#   'Navn': '5. Vest',
#   'Afstemningssted': {'Navn': 'Nørrebro Park Skole',
#    'Adgangsadresse': {'Id': '0a3f507a-9cb5-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Jagtvej 34, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704956',
#   'Nummer': 25,
#   'Navn': '5. Nordvest',
#   'Afstemningssted': {'Navn': 'Frederiksgård Skole',
#    'Adgangsadresse': {'Id': '0a3f507b-313d-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ørholmgade 8, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '706184',
#   'Nummer': 21,
#   'Navn': '5. Nord',
#   'Afstemningssted': {'Navn': 'Rådmandsgades Skole',
#    'Adgangsadresse': {'Id': '0a3f507a-ec40-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Rådmandsgade 22, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '703386',
#   'Nummer': 22,
#   'Navn': '5. Syd',
#   'Afstemningssted': {'Navn': 'Korsgadehallen',
#    'Adgangsadresse': {'Id': '0a3f507a-ae15-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Korsgade 29, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704962',
#   'Nummer': 23,
#   'Navn': '5. Øst',
#   'Afstemningssted': {'Navn': 'Plejecentret Sølund',
#    'Adgangsadresse': {'Id': '0a3f507a-e79f-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Ryesgade 20A, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '725352',
#   'Nummer': 58,
#   'Navn': '5. Nørrebrohallen',
#   'Afstemningssted': {'Navn': 'Nørrebrohallen',
#    'Adgangsadresse': {'Id': '0a3f507a-d117-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nørrebrogade 208, 2200 København N'}},
#   'Kommunekode': 101,
#   'Opstillingskredsnummer': 5,
#   'Opstillingskreds_Dagi_id': '403567',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705992',
#   'Nummer': 14,
#   'Navn': 'Vesterkærets Skole',
#   'Afstemningssted': {'Navn': 'Vesterkærets Skole',
#    'Adgangsadresse': {'Id': '0a3f509c-b4c2-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Skydebanevej 1, 9000 Aalborg'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705964',
#   'Nummer': 22,
#   'Navn': 'Frejlev Skoles Idrætshal',
#   'Afstemningssted': {'Navn': 'Frejlev Skoles Idrætshal',
#    'Adgangsadresse': {'Id': '0a3f509c-3d04-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Frejlev Skolevej 11, 9200 Aalborg SV'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704474',
#   'Nummer': 15,
#   'Navn': 'Haraldslund',
#   'Afstemningssted': {'Navn': 'Haraldslund, salen, fra P-pladsen',
#    'Adgangsadresse': {'Id': '0a3f509c-65a1-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Kastetvej 83, 9000 Aalborg'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '748031',
#   'Nummer': 20,
#   'Navn': 'Hasseris Gymnasium',
#   'Afstemningssted': {'Navn': 'Hasseris Gymnasium',
#    'Adgangsadresse': {'Id': '0a3f509c-4fdc-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Hasserisvej 300, 9000 Aalborg'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': '25-09-2025 18:00:38',
#   'Dagi_id': '705970',
#   'Nummer': 38,
#   'Navn': 'Ferslev Skole',
#   'Afstemningssted': {'Navn': 'Ferslev Skole',
#    'Adgangsadresse': {'Id': '0a3f509c-a840-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Rævedalsvej 5, 9230 Svenstrup J'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '705942',
#   'Nummer': 47,
#   'Navn': 'Nibe Hallen',
#   'Afstemningssted': {'Navn': 'Nibe Hallen, Hal B',
#    'Adgangsadresse': {'Id': '0a3f509b-0e39-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Hobrovej 36, Vokslev, 9240 Nibe'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710526',
#   'Nummer': 17,
#   'Navn': 'Skipperens Idrætshus',
#   'Afstemningssted': {'Navn': 'Skipperens Idrætshus',
#    'Adgangsadresse': {'Id': '39ece5fb-f8cd-0ee2-e044-0003ba298018',
#     'Adressebetegnelse': 'Provstejorden 15, 9000 Aalborg'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708924',
#   'Nummer': 24,
#   'Navn': 'Svenstruphallen',
#   'Afstemningssted': {'Navn': 'Svenstruphallen',
#    'Adgangsadresse': {'Id': '7db01d22-1107-4550-9ad2-f8e19f2df4b5',
#     'Adressebetegnelse': 'Svenstrup Skolevej 23, 9230 Svenstrup J'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704462',
#   'Nummer': 18,
#   'Navn': 'Hallen Ved Skalborggård',
#   'Afstemningssted': {'Navn': 'Hallen Ved Skalborggård',
#    'Adgangsadresse': {'Id': '0a3f509c-5828-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Hobrovej 437, 9200 Aalborg SV'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707350',
#   'Nummer': 52,
#   'Navn': 'Farstruphallen',
#   'Afstemningssted': {'Navn': 'Farstruphallen',
#    'Adgangsadresse': {'Id': '0a3f509b-126b-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Nymøllevej 118B, Farstrup, 9240 Nibe'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': '29-08-2025 08:32:09',
#   'Dagi_id': '701344',
#   'Nummer': 19,
#   'Navn': 'KFUM Hallen',
#   'Afstemningssted': {'Navn': 'KFUM Hallen',
#    'Adgangsadresse': {'Id': '0a3f509c-d874-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Under Lien 77, 9000 Aalborg'}},
#   'Kommunekode': 851,
#   'Opstillingskredsnummer': 91,
#   'Opstillingskreds_Dagi_id': '403595',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '704280',
#   'Nummer': 33,
#   'Navn': 'Paderup Gymnasium',
#   'Afstemningssted': {'Navn': 'Paderup Gymnasium',
#    'Adgangsadresse': {'Id': '0a3f5094-994b-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Apollovej 64, Paderup, 8960 Randers SØ'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711638',
#   'Nummer': 32,
#   'Navn': 'Tirsdalens Skole',
#   'Afstemningssted': {'Navn': 'Tirsdalens Skole',
#    'Adgangsadresse': {'Id': '0a3f5094-ccae-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'R. Hougårds Vej 50, 8960 Randers SØ'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '711624',
#   'Nummer': 28,
#   'Navn': 'Fritidscentret',
#   'Afstemningssted': {'Navn': 'Fritidscentret',
#    'Adgangsadresse': {'Id': '0a3f5094-de21-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Vestergade 15, 8900 Randers C'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702764',
#   'Nummer': 2,
#   'Navn': 'Stevnstrup Forsamlingshus',
#   'Afstemningssted': {'Navn': 'Stevnstrup Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5094-0466-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Landsbygaden 25, Stevnstrup, 8870 Langå'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '702770',
#   'Nummer': 25,
#   'Navn': 'Hobrovejens Skole',
#   'Afstemningssted': {'Navn': 'Hobrovejens Skole',
#    'Adgangsadresse': {'Id': '0a3f5094-a9f0-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Gethersvej 36, 8900 Randers C'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708738',
#   'Nummer': 17,
#   'Navn': 'Purhushallen',
#   'Afstemningssted': {'Navn': 'Purhushallen',
#    'Adgangsadresse': {'Id': '0a3f5094-88ac-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bakkevænget 12, 8990 Fårup'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '707204',
#   'Nummer': 37,
#   'Navn': 'Uggelhuse Forsamlingshus',
#   'Afstemningssted': {'Navn': 'Uggelhuse Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5095-bca6-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Bygaden 8, Uggelhuse, 8960 Randers SØ'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '701178',
#   'Nummer': 4,
#   'Navn': 'Jebjerg Forsamlingshus',
#   'Afstemningssted': {'Navn': 'Jebjerg Forsamlingshus',
#    'Adgangsadresse': {'Id': '0a3f5094-033f-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Jebjergvej 33, Jebjerg, 8870 Langå'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '708750',
#   'Nummer': 16,
#   'Navn': 'Asferg Træningshus',
#   'Afstemningssted': {'Navn': 'Asferg Træningshus',
#    'Adgangsadresse': {'Id': '1f289f18-9198-372c-e044-0003ba298018',
#     'Adressebetegnelse': 'Søndergade 17B, Asferg, 8990 Fårup'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  {'OprettetUtc': '11-08-2025 08:43:36',
#   'OpdateretUtc': None,
#   'Dagi_id': '710392',
#   'Nummer': 36,
#   'Navn': 'Assentofthallen',
#   'Afstemningssted': {'Navn': 'Assentofthallen',
#    'Adgangsadresse': {'Id': '0a3f5095-c896-32b8-e044-0003ba298018',
#     'Adressebetegnelse': 'Stadionvej 41, Assentoft, 8960 Randers SØ'}},
#   'Kommunekode': 730,
#   'Opstillingskredsnummer': 68,
#   'Opstillingskreds_Dagi_id': '403598',
#   'Type': 'Afstemningsområde'},
#  ...]

# %%
afstemningssteder = []

for d in data:

    afstemningssteder.append({
        'dagi_id': d['Dagi_id'],
        'navn': d['Navn'],
        'nummer': d['Nummer'],
        'afstemningssted_navn': d['Afstemningssted']['Navn'],
        'kommune_id': d['Kommunekode'],
        'opstillingskreds_nummer': d['Opstillingskredsnummer'],
        'opstillingskreds_dagi_id': d['Opstillingskreds_Dagi_id'],
        'afstemningssted_adresse': d['Afstemningssted']['Adgangsadresse']['Adressebetegnelse']
    })

df_afstemningssteder = pd.DataFrame(afstemningssteder)
df_afstemningssteder
# Out:
#      dagi_id                           navn  nummer  \
# 0     709812  Langå, Svindinge Og Øksendrup       5
# 1     748590                       Nymarken       3
# 2     706574                     Kerteminde       2
# 3     703760                      Skellerup       8
# 4     703754                   Nyborghallen       2
# ...      ...                            ...     ...
# 1309  707512                            Sig       4
# 1310  710690                          Ølgod      30
# 1311  708972                        Blåvand      19
# 1312  704694                        Agerbæk      23
# 1313  701482                        Ansager      32
#
#                            afstemningssted_navn  kommune_id  \
# 0                      Svindinge Forsamlingshus         450
# 1                                 Nymarksskolen         440
# 2                       Kerteminde Idrætscenter         440
# 3                      Skellerup Forsamlingshus         450
# 4                                  Nyborghallen         450
# ...                                         ...         ...
# 1309                   Birgittegården, Rød Stue         573
# 1310  Ølgod Hallen - Bemærk NYT afstemningssted         573
# 1311                          Blåvand Borgerhus         573
# 1312                              Agerbæk Hotel         573
# 1313       Skovlund-Ansager Hallen, Mini-hallen         573
#
#       opstillingskreds_nummer opstillingskreds_dagi_id  \
# 0                          46                   403614
# 1                          46                   403614
# 2                          46                   403614
# 3                          46                   403614
# 4                          46                   403614
# ...                       ...                      ...
# 1309                       54                   403620
# 1310                       54                   403620
# 1311                       54                   403620
# 1312                       54                   403620
# 1313                       54                   403620
#
#                      afstemningssted_adresse
# 0           Strædet 2, Svindinge, 5853 Ørbæk
# 1     Nymarken 47, Hundslev, 5300 Kerteminde
# 2                Enggade 19, 5300 Kerteminde
# 3         Skellerup Byvej 16, 5540 Ullerslev
# 4                      Halvej 1, 5800 Nyborg
# ...                                      ...
# 1309            Falkevej 4A, Sig, 6800 Varde
# 1310                Skolegade 18, 6870 Ølgod
# 1311            Blåvandvej 30A, 6857 Blåvand
# 1312               Storegade 7, 6753 Agerbæk
# 1313               Lærkevej 16, 6823 Ansager
#
# [1314 rows x 8 columns]

# %%
kommune_info = json.load(open("data/kommuner.json", "r", encoding="utf-8"))

# %%
#turnto dataframe
df_kommune_info = pd.DataFrame(kommune_info)
df_kommune_info
# Out:
#    kommune_id   kommune_navn  kommune_dagi_id chart_id table_id map_id  \
# 0         101      København         389103.0     None     None   None
# 1         147  Frederiksberg         389104.0     None     None   None
# 2         151       Ballerup         389105.0     None     None   None
# 3         153        Brøndby         389106.0     None     None   None
# 4         155         Dragør         389107.0     None     None   None
# ..        ...            ...              ...      ...      ...    ...
# 94        840         Rebild         389204.0     None     None   None
# 95        846  Mariagerfjord         389202.0     None     None   None
# 96        849     Jammerbugt         389205.0     None     None   None
# 97        851        Aalborg         389206.0     None     None   None
# 98        860       Hjørring         389201.0     None     None   None
#
#          region
# 0    Østdanmark
# 1    Østdanmark
# 2    Østdanmark
# 3    Østdanmark
# 4    Østdanmark
# ..          ...
# 94  Nordjylland
# 95  Nordjylland
# 96  Nordjylland
# 97  Nordjylland
# 98  Nordjylland
#
# [99 rows x 7 columns]

# %%
#turn kommune_id to an int
df_kommune_info['kommune_id'] = df_kommune_info['kommune_id'].astype(int)
#join region on df_afstemningssteder
df_merged = df_afstemningssteder.merge(df_kommune_info[['kommune_id', 'region']], on='kommune_id', how='left')

# %%
df_merged
# Out:
#      dagi_id                           navn  nummer  \
# 0     709812  Langå, Svindinge Og Øksendrup       5
# 1     748590                       Nymarken       3
# 2     706574                     Kerteminde       2
# 3     703760                      Skellerup       8
# 4     703754                   Nyborghallen       2
# ...      ...                            ...     ...
# 1309  707512                            Sig       4
# 1310  710690                          Ølgod      30
# 1311  708972                        Blåvand      19
# 1312  704694                        Agerbæk      23
# 1313  701482                        Ansager      32
#
#                            afstemningssted_navn  kommune_id  \
# 0                      Svindinge Forsamlingshus         450
# 1                                 Nymarksskolen         440
# 2                       Kerteminde Idrætscenter         440
# 3                      Skellerup Forsamlingshus         450
# 4                                  Nyborghallen         450
# ...                                         ...         ...
# 1309                   Birgittegården, Rød Stue         573
# 1310  Ølgod Hallen - Bemærk NYT afstemningssted         573
# 1311                          Blåvand Borgerhus         573
# 1312                              Agerbæk Hotel         573
# 1313       Skovlund-Ansager Hallen, Mini-hallen         573
#
#       opstillingskreds_nummer opstillingskreds_dagi_id  \
# 0                          46                   403614
# 1                          46                   403614
# 2                          46                   403614
# 3                          46                   403614
# 4                          46                   403614
# ...                       ...                      ...
# 1309                       54                   403620
# 1310                       54                   403620
# 1311                       54                   403620
# 1312                       54                   403620
# 1313                       54                   403620
#
#                      afstemningssted_adresse      region
# 0           Strædet 2, Svindinge, 5853 Ørbæk  Syddanmark
# 1     Nymarken 47, Hundslev, 5300 Kerteminde  Syddanmark
# 2                Enggade 19, 5300 Kerteminde  Syddanmark
# 3         Skellerup Byvej 16, 5540 Ullerslev  Syddanmark
# 4                      Halvej 1, 5800 Nyborg  Syddanmark
# ...                                      ...         ...
# 1309            Falkevej 4A, Sig, 6800 Varde  Syddanmark
# 1310                Skolegade 18, 6870 Ølgod  Syddanmark
# 1311            Blåvandvej 30A, 6857 Blåvand  Syddanmark
# 1312               Storegade 7, 6753 Agerbæk  Syddanmark
# 1313               Lærkevej 16, 6823 Ansager  Syddanmark
#
# [1314 rows x 9 columns]

# %%
# for each kommune dagi id generate a csv file with the afstemningssteder for that kommune
output_dir = 'data/struktureret/rv/valgresultater/afstemningssteder/'

os.makedirs(output_dir, exist_ok=True)

num = 0
for region, group in df_merged.groupby('region'):
    region_navn = group['region'].iloc[0].lower().replace(' ', '_')
    output_file = os.path.join(output_dir, f'{region_navn}_afstemningsområde.csv')
    group['største_parti'] = ''  # placeholder column for største parti
    group.to_csv(output_file, index=False)
    num += 1
print(f'Wrote afstemningssteder for {num} regioner to {output_dir}')
# Out:
# Wrote afstemningssteder for 4 regioner to data/struktureret/rv/valgresultater/afstemningssteder/

# %%
# also generate a file for each kommune in the folder data/struktureret/kv/valgresultater/kommune/
output_dir_kommune = 'data/struktureret/rv/valgresultater/region/'

os.makedirs(output_dir_kommune, exist_ok=True)
# the file should have the columns: kommune_id, kommune_dagi_id, kommune_navn, parti, procent_25, stemmer_25, procent_21, stemmer_21

for region, group in df_merged.groupby('region'):
    region_navn = group['region'].iloc[0].lower().replace(' ', '_')
    output_file = os.path.join(output_dir_kommune, f'{region_navn}.csv')
    df_kommune = pd.DataFrame([{
        'region_navn': group['region'].iloc[0],
        'partier': '',
        'procent_25': '',
        'stemmer_25': '',
        'procent_21': '',
        'stemmer_21': ''
    }])
    df_kommune.to_csv(output_file, index=False)

# %%
regioner_geo = json.load(open("data/shapes/regioner_afstemningsområder.geojson"))

# %%
# the file has shapes for five regions and their afstemningsområder
old_regioner = ['Region Hovedstaden', 'Region Sjælland', 'Region Syddanmark', 'Region Midtjylland', 'Region Nordjylland']
new_regioner = ['Region Østdanmark', 'Region Syddanmark', 'Region Midtjylland', 'Region Nordjylland']

# split the geojson into separate files for each new region
for region in new_regioner:
    region_geo = {
        "type": "FeatureCollection",
        "features": []
    }
    for feature in regioner_geo['features']:
        if region == 'Region Østdanmark':
            if feature['properties']['regionsnavn'] in ['Region Hovedstaden', 'Region Sjælland']:
                region_geo['features'].append(feature)
        else:
            if feature['properties']['regionsnavn'] == region:
                region_geo['features'].append(feature)
    with open(f"data/shapes/{region.lower().replace(' ', '_')}_afstemningsområder.geojson", "w") as f:
        json.dump(region_geo, f)

# %%
# turn data/kommuner.json into a dataframe
df_kommuner = pd.DataFrame(kommune_info)

# %%
df_kommuner.to_clipboard()

# %%
# loop over each kommune in kommune info and print the kommune_id and kommune_navn
for region, group in df_merged.groupby('region'):
    # create a dataframe with the columns    kommune_id kommune_navn  andel_af_afstemningssteder_talt  borgmester
    df = pd.DataFrame({
        'region_navn': [group['region']],
        'andel_af_afstemningssteder_talt': 0,
        'Regionsrådsforperson': "Ikke afgjort"
    })
    # save the dataframe to a csv file in data/struktureret/kv/valgresultater/status/
    region_navn = group['region'].iloc[0].lower().replace(' ', '_')

    #df.to_csv(f"data/struktureret/rv/valgresultater/status/{region_navn}_status.csv", index=False)
# Out:
#                                          region_navn  \
# 0  19      Midtjylland
# 20      Midtjylland
# 21    ...
#
#    andel_af_afstemningssteder_talt Regionsrådsforperson
# 0                                0         Ikke afgjort
#                                          region_navn  \
# 0  62      Nordjylland
# 63      Nordjylland
# 64    ...
#
#    andel_af_afstemningssteder_talt Regionsrådsforperson
# 0                                0         Ikke afgjort
#                                          region_navn  \
# 0  0       Syddanmark
# 1       Syddanmark
# 2       ...
#
#    andel_af_afstemningssteder_talt Regionsrådsforperson
# 0                                0         Ikke afgjort
#                                          region_navn  \
# 0  33      Østdanmark
# 34      Østdanmark
# 35      ...
#
#    andel_af_afstemningssteder_talt Regionsrådsforperson
# 0                                0         Ikke afgjort

# %%
# for each kommune dagi id generate a csv file with the afstemningssteder for that kommune
output_dir = 'data/struktureret/rv/valgresultater/afstemningssteder/'

os.makedirs(output_dir, exist_ok=True)

num = 0
for kommune_id, group in df_afstemningssteder.groupby('kommune_id'):
    kommune_navn = group['kommune_navn'].iloc[0].lower().replace(' ', '_')
    output_file = os.path.join(output_dir, f'{kommune_id}_{kommune_navn}_afstemningsområde.csv')
    group['største_parti'] = ''  # placeholder column for største parti
    group.to_csv(output_file, index=False)
    num += 1
print(f'Wrote afstemningssteder for {num} kommuner to {output_dir}')
